# %%
import pandas as pd

# %%
df = pd.read_csv("exam_scores.csv")
df.head()
# Out:
#       name  score
# 0    Rishi     78
# 1    Arjun     71
# 2  Lakshmi     68
# 3    Aditi     81
# 4    Aisha     85

# %%
from scipy import stats

population_mean = 72

t_one_sample ,p_value_one_sample = stats.ttest_1samp(df.score,population_mean,alternative = "greater")
t_one_sample ,p_value_one_sample
# Out:
# (np.float64(2.228523555325052), np.float64(0.019059543933267795))

# %%
t_critical = 1.729
