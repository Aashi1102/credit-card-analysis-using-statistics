# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("control_group.csv")
df
# Out:
#     person_id  recovery_time_hrs
# 0        C001                4.4
# 1        C002                4.1
# 2        C003                3.2
# 3        C004                4.3
# 4        C005                4.9
# ..        ...                ...
# 125      C126                3.9
# 126      C127                3.8
# 127      C128                4.2
# 128      C129                4.3
# 129      C130                4.2
#
# [130 rows x 2 columns]

# %%
df.shape
# Out:
# (130, 2)

# %%
n1 = 130

# %%
m1 = df.recovery_time_hrs.mean().round(2)
m1
# Out:
# np.float64(3.91)

# %%
std1 = df.recovery_time_hrs.std().round(2)
std1
# Out:
# np.float64(0.32)

# %%
df_test = pd.read_csv("test_group.csv")
df_test
# Out:
#    person_id  recovery_time_hrs
# 0       T001                3.7
# 1       T002                4.1
# 2       T003                3.7
# 3       T004                3.9
# 4       T005                3.7
# ..       ...                ...
# 95      T096                3.9
# 96      T097                3.9
# 97      T098                4.9
# 98      T099                3.7
# 99      T100                3.8
#
# [100 rows x 2 columns]

# %%
df_test.shape
# Out:
# (100, 2)

# %%
n2 = 100

# %%
m2 = df_test.recovery_time_hrs.mean().round(2)
m2
# Out:
# np.float64(3.91)

# %%
std2 = df_test.recovery_time_hrs.std().round(2)
std2
# Out:
# np.float64(0.32)

# %%
a = std1**2/n1
b = std2**2/n2

a,b
# Out:
# (np.float64(0.0007876923076923077), np.float64(0.001024))

# %%
z_score = (m1-m2)/np.sqrt(a+b)
z_score
# Out:
# np.float64(0.0)
